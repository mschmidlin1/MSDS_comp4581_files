# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Metro.csv")
df = df[['RegionName', '2019-01', '2020-01']]
df=df.iloc[1:]
df = df.reset_index().drop(columns=['index'])
df['roi'] = df['2020-01'] - df['2019-01']
df.rename(columns={'2020-01': 'cost'}, inplace=True)
df.drop(columns=['2019-01'], inplace=True)
options = df.values.tolist()
options[:10]
# Out:
#                              RegionName    cost    roi
# 0                          New York, NY  481486   3841
# 1    Los Angeles-Long Beach-Anaheim, CA  674786  15235
# 2                           Chicago, IL  238978   2432
# 3                 Dallas-Fort Worth, TX  253299   5559
# 4                      Philadelphia, PA  248836   7541
# ..                                  ...     ...    ...
# 605                         Ardmore, OK   96258   6360
# 606                    Kendallville, IN  139742   8379
# 607                         Nogales, AZ  163844   7627
# 608                          Oxford, MS  195667   9264
# 609                        Bogalusa, LA   99998   2562
#
# [610 rows x 3 columns]

# %%
options = sorted(options, key=lambda x: x[1])

# %%
options
# Out:
# [['Rio Grande City, TX', 59179, 868],
#  ['Freeport, IL', 64103, 2138],
#  ['Pine Bluff, AR', 64234, 2333],
#  ['Roanoke Rapids, NC', 67185, 985],
#  ['Danville, IL', 68060, 1371],
#  ['Lumberton, NC', 74718, 2138],
#  ['Johnstown, PA', 76981, 4410],
#  ['Big Stone Gap, VA', 77739, 1272],
#  ['Galesburg, IL', 78216, 2387],
#  ['Bluefield, WV', 78478, 2312],
#  ['Beckley, WV', 79569, 1696],
#  ['Muskogee, OK', 80274, 4260],
#  ['Martinsville, VA', 81836, 2254],
#  ['Pottsville, PA', 82162, 5862],
#  ['Gaffney, SC', 83349, 2413],
#  ['Portsmouth, OH', 84256, 3047],
#  ['Ogdensburg, NY', 84761, 4455],
#  ['Olean, NY', 85178, 2940],
#  ['Oil City, PA', 85877, 3535],
#  ['Weirton, OH', 85931, 4354],
#  ['Marion, IN', 87655, 3790],
#  ['Charleston, IL', 89176, 1147],
#  ['Enid, OK', 89396, 2106],
#  ['Decatur, IL', 90241, -2616],
#  ['Kinston, NC', 91273, 1697],
#  ['Fort Madison, IA', 91760, 2325],
#  ['Point Pleasant, WV', 93306, 3596],
#  ['Muncie, IN', 93960, 3232],
#  ['Lawton, OK', 94893, 3028],
#  ['Ozark, AL', 94987, 3139],
#  ['Natchez, MS', 95612, 1756],
#  ['Charleston, WV', 95734, -1374],
#  ['Ardmore, OK', 96258, 6360],
#  ['Waycross, GA', 96276, 3280],
#  ['Saginaw, MI', 96328, 6729],
#  ['Orangeburg, SC', 97167, 1082],
#  ['Youngstown, OH', 97180, 4289],
#  ['Terre Haute, IN', 97373, 3364],
#  ['New Castle, IN', 97624, 4970],
#  ['Shawnee, OK', 98241, 6339],
#  ['Gadsden, AL', 99262, 3954],
#  ['Bogalusa, LA', 99998, 2562],
#  ['Wichita Falls, TX', 100038, -946],
#  ['Meridian, MS', 100042, 3984],
#  ['London, KY', 100211, 4780],
#  ['DuBois, PA', 100273, 3558],
#  ['Wheeling, OH', 100403, 4790],
#  ['Salem, OH', 100557, 3800],
#  ['Laurel, MS', 100896, 3331],
#  ['Cumberland, MD', 101717, 4224],
#  ['Hutchinson, KS', 101738, 2635],
#  ['Elmira, NY', 102030, 373],
#  ['Marion, OH', 102126, 4739],
#  ['Jamestown, NY', 102165, 8865],
#  ['Danville, VA', 102370, 3394],
#  ['Burlington, IA', 102394, 2796],
#  ['Marinette, WI', 102429, 5018],
#  ['McComb, MS', 102648, 2623],
#  ['Roswell, NM', 102763, 4809],
#  ['Richmond, IN', 103130, 2611],
#  ['Paducah, KY', 103243, 4912],
#  ['Clarksburg, WV', 103244, 4185],
#  ['Anniston, AL', 103331, 5572],
#  ['Bartlesville, OK', 103911, 3305],
#  ['Huntington, WV', 104166, 3843],
#  ['Dublin, GA', 105089, 3467],
#  ['Carbondale, IL', 105445, 3281],
#  ['New Castle, PA', 105493, 4736],
#  ['Talladega, AL', 105877, 5357],
#  ['Meadville, PA', 106583, 4189],
#  ['Corning, NY', 107050, 3130],
#  ['Shreveport, LA', 107169, -1569],
#  ['Lima, OH', 107516, 4388],
#  ['Palestine, TX', 107578, 2326],
#  ['Rocky Mount, NC', 107755, 5421],
#  ['Shelby, NC', 108249, 3940],
#  ['Fort Smith, AR', 108516, 4441],
#  ['Glasgow, KY', 108814, 6302],
#  ['Parkersburg, WV', 108872, 4714],
#  ['Brownsville, TX', 109021, 5258],
#  ['Macon-Bibb County, GA', 109194, 5122],
#  ['Mansfield, OH', 109268, 8528],
#  ['Sterling, IL', 109369, 2339],
#  ['Corsicana, TX', 109385, 5168],
#  ['Ashtabula, OH', 109406, 7215],
#  ['Somerset, PA', 109449, 3819],
#  ['Tiffin, OH', 109588, 5002],
#  ['Fairmont, WV', 109819, 5146],
#  ['Scottsboro, AL', 110522, 1884],
#  ['Albany, GA', 110668, 1448],
#  ['Ottawa, IL', 110808, 198],
#  ['Sunbury, PA', 110910, 4127],
#  ['Paris, TX', 111206, 4784],
#  ['Texarkana, TX', 111248, 4183],
#  ['Malone, NY', 112345, 5444],
#  ['Florence, SC', 112526, 2836],
#  ['Altoona, PA', 112720, 3304],
#  ['Greenwood, SC', 113482, 4650],
#  ['Morgan City, LA', 113678, 1585],
#  ['Greeneville, TN', 113818, 9182],
#  ['Peoria, IL', 113967, 1183],
#  ['Kokomo, IN', 114136, 7459],
#  ['Russellville, AR', 115264, 6440],
#  ['Springfield, OH', 115336, 5259],
#  ['Norwalk, OH', 115406, 6170],
#  ['McAllen, TX', 115920, 6090],
#  ['Dothan, AL', 115971, 3447],
#  ['Columbus, MS', 116203, 4512],
#  ['Athens, OH', 116898, 4878],
#  ['Vicksburg, MS', 116930, 4575],
#  ['Amsterdam, NY', 118382, 4463],
#  ['Scranton, PA', 118508, 5484],
#  ['Tupelo, MS', 118595, 3882],
#  ['Opelousas, LA', 118677, 2409],
#  ['Searcy, AR', 118714, -4857],
#  ['Farmington, MO', 118745, 5312],
#  ['Jackson, TN', 119160, 6377],
#  ['Jacksonville, TX', 119457, 4496],
#  ['Owosso, MI', 119808, 6482],
#  ['St. Joseph, MO', 120171, 6402],
#  ['Binghamton, NY', 120337, 1767],
#  ['Quincy, IL', 120497, 4774],
#  ['Mason City, IA', 120949, 3778],
#  ['Rockford, IL', 121505, 4835],
#  ['Sumter, SC', 122033, 4108],
#  ['Manitowoc, WI', 122207, 5282],
#  ['Danville, KY', 122349, 5177],
#  ['Columbus, GA', 122486, 4898],
#  ['Zanesville, OH', 122932, 8557],
#  ['Forest City, NC', 123518, 5114],
#  ['Toledo, OH', 123524, 7002],
#  ['Fremont, OH', 123739, 4787],
#  ['LaGrange, GA', 124019, 3512],
#  ['Wilson, NC', 124105, 3544],
#  ['Beaumont, TX', 124248, 2643],
#  ['Chillicothe, OH', 125128, 6831],
#  ['Flint, MI', 125399, 8862],
#  ['Albertville, AL', 125452, 6953],
#  ['Florence, AL', 125454, 3699],
#  ['Del Rio, TX', 125555, 5676],
#  ['Montgomery, AL', 125680, 3479],
#  ['Alexandria, LA', 125817, -2233],
#  ['Bay City, MI', 126152, 8326],
#  ['Valdosta, GA', 126520, 4167],
#  ['Salina, KS', 126689, 4213],
#  ['Cadillac, MI', 126765, 6854],
#  ['Marietta, OH', 126961, 6810],
#  ['Enterprise, AL', 127017, 4519],
#  ['Owensboro, KY', 127247, 5077],
#  ['Palatka, FL', 127258, 11552],
#  ['Indiana, PA', 127265, 4670],
#  ['Mobile, AL', 127684, 6445],
#  ['Lufkin, TX', 127947, 4993],
#  ['Goldsboro, NC', 128118, 3540],
#  ['New Philadelphia, OH', 128124, -6126],
#  ['Jonesboro, AR', 128229, 6766],
#  ['Erie, PA', 128857, 4026],
#  ['Gloversville, NY', 129434, 4812],
#  ['Joplin, MO', 129862, 15137],
#  ['Wisconsin Rapids-Marshfield, WI', 130026, 5784],
#  ['Battle Creek, MI', 130555, 7717],
#  ['Greenville, OH', 130926, 3926],
#  ['Rome, GA', 131029, 10764],
#  ['Milledgeville, GA', 131093, 4276],
#  ['Fayetteville, NC', 131825, 4897],
#  ['Auburn, NY', 132181, 4359],
#  ['North Wilkesboro, NC', 132386, 4910],
#  ['Decatur, AL', 132527, 6667],
#  ['Mount Airy, NC', 132604, 3930],
#  ['Cortland, NY', 133188, 5392],
#  ['Batavia, NY', 133397, 6560],
#  ['Alamogordo, NM', 133421, 11107],
#  ['South Bend, IN', 133673, 5706],
#  ['Davenport, IL', 133679, 3515],
#  ['Topeka, KS', 133763, 6487],
#  ['Sturgis, MI', 133843, 13064],
#  ['Dayton, OH', 134460, 8267],
#  ['Rochelle, IL', 134548, 2850],
#  ['Springfield, IL', 134782, 1394],
#  ['El Paso, TX', 134937, 5574],
#  ['Abilene, TX', 135114, 2602],
#  ['Utica, NY', 135775, 6741],
#  ['Kingsport, TN', 136441, 5549],
#  ['Cullman, AL', 136516, 6827],
#  ['Athens, TN', 136931, 5475],
#  ['Eagle Pass, TX', 137258, 4916],
#  ['Marshall, TX', 137449, 3748],
#  ['Gulfport, MS', 137501, 5746],
#  ['Sayre, PA', 138122, 4367],
#  ['Canton, OH', 138397, 8611],
#  ['Vineland, NJ', 138408, -1387],
#  ['Dalton, GA', 138962, 6025],
#  ['Picayune, MS', 139065, 2431],
#  ['Fond du Lac, WI', 139336, 6318],
#  ['Kendallville, IN', 139742, 8379],
#  ['Platteville, WI', 140015, 7636],
#  ['Sandusky, OH', 140266, 6406],
#  ['Washington, NC', 140336, 3435],
#  ['Sebring, FL', 140337, 4352],
#  ['Waterloo, IA', 140967, 3335],
#  ['Midland, MI', 141082, 4055],
#  ['Amarillo, TX', 141602, 3493],
#  ['Sioux City, IA', 141726, 1265],
#  ['Jackson, MS', 142145, 4868],
#  ['Hattiesburg, MS', 142215, 5595],
#  ['Watertown, NY', 142358, 3031],
#  ['Evansville, IN', 142559, 6616],
#  ['Fort Polk South, LA', 142637, 1855],
#  ['Warner Robins, GA', 142860, 5554],
#  ['Greenville, NC', 142885, 6707],
#  ['Wichita, KS', 143183, 6110],
#  ['Plattsburgh, NY', 143452, 5142],
#  ['Mount Pleasant, MI', 143723, 6915],
#  ['Ashland, OH', 143852, 7529],
#  ['Sanford, NC', 144188, 3562],
#  ['Champaign-Urbana, IL', 144316, 3273],
#  ['Ionia, MI', 144583, 13454],
#  ['San Angelo, TX', 144671, -5],
#  ['Syracuse, NY', 144866, 5564],
#  ['Lubbock, TX', 145102, 4075],
#  ['Bloomington, IL', 145171, 1639],
#  ['Calhoun, GA', 145563, 6304],
#  ['Sidney, OH', 145776, 7196],
#  ['Clinton, IA', 146130, 5030],
#  ['Muskegon, MI', 146486, 8921],
#  ['Kankakee, IL', 146729, 5539],
#  ['Somerset, KY', 146804, 6801],
#  ['Little Rock, AR', 148031, 2104],
#  ['Hickory, NC', 148118, 8450],
#  ['Mount Vernon, OH', 148435, 11181],
#  ['Tulsa, OK', 148498, 4986],
#  ['Morristown, TN', 149044, 10721],
#  ['Hammond, LA', 149193, 5071],
#  ['Monroe, LA', 150629, 1407],
#  ['Fort Wayne, IN', 150717, 10356],
#  ['Hot Springs, AR', 150901, 5929],
#  ['Albemarle, NC', 151296, 6664],
#  ['Sheboygan, WI', 151329, 7893],
#  ['Stillwater, OK', 151781, 8653],
#  ['Elizabethtown, KY', 151825, 6963],
#  ['Michigan City, IN', 151852, 6461],
#  ['Augusta, GA', 152098, 4523],
#  ['Akron, OH', 152159, 7124],
#  ['Tullahoma, TN', 152328, 5253],
#  ['Janesville, WI', 152482, 9133],
#  ['Spartanburg, SC', 152722, 8508],
#  ['Laredo, TX', 152942, -3318],
#  ['Hinesville, GA', 152992, 1884],
#  ['Frankfort, KY', 153138, 7373],
#  ['Jasper, IN', 153158, 7671],
#  ['Killeen, TX', 153314, 8324],
#  ['Jackson, MI', 153662, 5219],
#  ['Athens, TX', 153678, 9512],
#  ['Memphis, TN', 153866, 9895],
#  ['Johnson City, TN', 154188, 5497],
#  ['Nacogdoches, TX', 154949, 6111],
#  ['Greensboro, NC', 155191, 9730],
#  ['Oneonta, NY', 155261, 6208],
#  ['Oshkosh, WI', 155413, 10557],
#  ['Longview, TX', 155604, 3880],
#  ['Findlay, OH', 156084, 10821],
#  ['Birmingham, AL', 156186, 9250],
#  ['Rochester, NY', 156242, 6414],
#  ['Bangor, ME', 156281, 4972],
#  ['Oklahoma City, OK', 156350, 7367],
#  ['Adrian, MI', 156742, 9618],
#  ['Norfolk, NE', 156860, 6704],
#  ['Lafayette, LA', 157100, 3229],
#  ['Cookeville, TN', 157123, 8987],
#  ['Cape Girardeau, MO', 157139, 10719],
#  ['Springfield, MO', 157479, 9572],
#  ['Pittsburgh, PA', 157983, 6853],
#  ['Lake City, FL', 158165, 4504],
#  ['Statesboro, GA', 158346, 5060],
#  ['Cleveland, OH', 158559, 6767],
#  ['Williamsport, PA', 158758, 8727],
#  ['New Bern, NC', 159047, 7864],
#  ['Jefferson City, MO', 159119, 4872],
#  ['Winston-Salem, NC', 159531, 9797],
#  ['Fort Leonard Wood, MO', 159865, 3861],
#  ['Elizabeth City, NC', 160006, 2729],
#  ['Columbia, SC', 160106, 5823],
#  ['Cedar Rapids, IA', 160456, 4561],
#  ['Sierra Vista, AZ', 160538, 13360],
#  ['Corpus Christi, TX', 161430, 6555],
#  ['Branson, MO', 161706, 7636],
#  ['Waco, TX', 161788, 7043],
#  ['Clarksville, TN', 161932, 6208],
#  ['Clovis, NM', 161979, 7497],
#  ['Lansing, MI', 162910, 7574],
#  ['Grand Island, NE', 163580, 6902],
#  ['Yuma, AZ', 163642, 12042],
#  ['Crossville, TN', 163650, 10583],
#  ['Nogales, AZ', 163844, 7627],
#  ['Elkhart, IN', 163855, 6218],
#  ['Wooster, OH', 163933, 4737],
#  ['Bloomsburg, PA', 164153, 6672],
#  ['Houma, LA', 164585, 617],
#  ['Hobbs, NM', 164918, 10344],
#  ['Burlington, NC', 165356, 10818],
#  ['Gallup, NM', 165895, 8397],
#  ['Homosassa Springs, FL', 166071, 6075],
#  ['Tuscaloosa, AL', 166278, 7439],
#  ['Bowling Green, KY', 167034, 7286],
#  ['Richmond, KY', 167173, 9034],
#  ['Marquette, MI', 167569, 6750],
#  ['Lafayette-West Lafayette, IN', 167842, 11160],
#  ['Beaver Dam, WI', 167967, 5946],
#  ['Jacksonville, NC', 168747, 12256],
#  ['Duluth, MN', 168820, 11035],
#  ['Cleveland, TN', 169085, 8761],
#  ['Las Cruces, NM', 169338, -4472],
#  ['Wausau, WI', 170001, 9972],
#  ['Ocala, FL', 170384, 10105],
#  ['Monroe, MI', 170411, 7050],
#  ['Morgantown, WV', 170592, 4192],
#  ['Augusta, ME', 170779, 7002],
#  ['Warrensburg, MO', 170795, 7615],
#  ['Seneca, SC', 171711, 6967],
#  ['Kalamazoo, MI', 172063, 8732],
#  ['Lake Charles, LA', 172415, 1473],
#  ['Tyler, TX', 172449, 16905],
#  ['Columbus, IN', 172737, 10623],
#  ['Buffalo, NY', 173282, 9387],
#  ['East Stroudsburg, PA', 173939, 11223],
#  ['Huntsville, TX', 174883, 8066],
#  ['Chattanooga, TN', 174894, 8254],
#  ['St. Marys, GA', 175525, 6441],
#  ['Sherman, TX', 175534, 5654],
#  ['Starkville, MS', 176465, 1245],
#  ['Dunn, NC', 177111, 14500],
#  ['Farmington, NM', 177490, 8898],
#  ['Chambersburg, PA', 177672, 4251],
#  ['Lynchburg, VA', 177962, 5893],
#  ['St. Louis, MO', 179019, 5477],
#  ['Detroit, MI', 179078, 6252],
#  ['Indianapolis, IN', 179994, 8068],
#  ['Louisville-Jefferson County, KY', 180331, 9757],
#  ['Green Bay, WI', 181569, 8946],
#  ['Eau Claire, WI', 181902, 11943],
#  ['Appleton, WI', 182960, 10032],
#  ['Oxford, NC', 183801, 7915],
#  ['Tallahassee, FL', 183900, 4697],
#  ['Dubuque, IA', 183921, 6815],
#  ['Niles, MI', 183964, 12309],
#  ['Roanoke, VA', 184401, 8378],
#  ['Warsaw, IN', 184707, 9967],
#  ['Lebanon, PA', 184722, 6666],
#  ['Stevens Point, WI', 184749, 8749],
#  ['Baton Rouge, LA', 184877, -352],
#  ['Rutland, VT', 184985, 6986],
#  ['Cincinnati, OH', 185009, 8737],
#  ['Lewiston, ME', 185191, 13075],
#  ['La Crosse, WI', 187712, 9059],
#  ['Pensacola, FL', 188520, 7816],
#  ['Glens Falls, NY', 188918, 4626],
#  ['Harrisburg, PA', 189508, 5366],
#  ['Knoxville, TN', 189696, 11834],
#  ['Lexington, KY', 190151, 8419],
#  ['Klamath Falls, OR', 190630, 13771],
#  ['Huntsville, AL', 190732, 12046],
#  ['Reading, PA', 190912, 8427],
#  ['Columbia, MO', 191467, 7201],
#  ['Ontario, OR', 192580, 12076],
#  ['Lakeland, FL', 192850, 8367],
#  ['Blacksburg, VA', 192859, 8293],
#  ['Pueblo, CO', 192939, 13734],
#  ['York, PA', 193003, 9446],
#  ['Odessa, TX', 194058, 12382],
#  ['Winona, MN', 195123, 7503],
#  ['Oxford, MS', 195667, 9264],
#  ['Great Falls, MT', 195692, 6868],
#  ['Brunswick, GA', 196113, 3987],
#  ['Fayetteville, AR', 196114, 10131],
#  ['Greenville, SC', 196948, 8399],
#  ['Pocatello, ID', 197793, 17323],
#  ['Omaha, NE', 197946, 10264],
#  ['Gainesville, FL', 197994, 10289],
#  ['Auburn, AL', 198317, 6728],
#  ['Lincoln, NE', 198353, 7157],
#  ['Aberdeen, WA', 198696, 15260],
#  ['Manhattan, KS', 200402, 6567],
#  ['Atlantic City, NJ', 200413, 8310],
#  ['Staunton, VA', 200648, 7195],
#  ['Bloomington, IN', 200774, 13657],
#  ['Hermiston-Pendleton, OR', 201137, 9937],
#  ['Des Moines, IA', 201835, 5512],
#  ['Hagerstown, WV', 202246, 6260],
#  ['Holland, MI', 202851, 10895],
#  ['Savannah, GA', 203237, 7534],
#  ['Kearney, NE', 203378, 8774],
#  ['San Antonio, TX', 203705, 7811],
#  ['New Orleans, LA', 203762, 8515],
#  ['Kansas City, MO', 203873, 6989],
#  ['Ames, IA', 204591, 5661],
#  ['Myrtle Beach, SC', 206720, 5493],
#  ['Albany, NY', 206768, 5295],
#  ['Baraboo, WI', 208730, 21518],
#  ['Brainerd, MN', 209205, 17303],
#  ['Roseburg, OR', 209874, 12455],
#  ['Albuquerque, NM', 210144, 12324],
#  ['Casper, WY', 210231, 10704],
#  ['Grand Forks, ND', 210505, 4186],
#  ['Columbus, OH', 210615, 12234],
#  ['Sioux Falls, SD', 210619, 6192],
#  ['St. Cloud, MN', 210784, 5358],
#  ['Athens, GA', 210898, 13812],
#  ['College Station, TX', 211028, 4434],
#  ['Keene, NH', 211910, 9527],
#  ['Allentown, PA', 211981, 5360],
#  ['Gettysburg, PA', 213551, 5680],
#  ['Ithaca, NY', 213656, -2760],
#  ['Daphne, AL', 215087, 9071],
#  ['Milwaukee, WI', 216600, 11254],
#  ['Houston, TX', 217159, 5130],
#  ['Punta Gorda, FL', 217905, 3408],
#  ['Greenfield Town, MA', 218145, -11526],
#  ['Panama City, FL', 218249, 10779],
#  ['Moses Lake, WA', 218344, 20084],
#  ['Harrisonburg, VA', 218776, 9082],
#  ['Twin Falls, ID', 218912, 18314],
#  ['Mankato, MN', 219004, 5593],
#  ['Grand Rapids, MI', 219009, 12716],
#  ['Daytona Beach, FL', 219692, 12086],
#  ['Show Low, AZ', 220077, 11872],
#  ['Minot, ND', 220438, 8542],
#  ['Claremont, NH', 220721, 9516],
#  ['Lawrence, KS', 221478, 11352],
#  ['Pinehurst-Southern Pines, NC', 222155, 9833],
#  ['Visalia, CA', 222245, 4369],
#  ['Coos Bay, OR', 222605, 13956],
#  ['Iowa City, IA', 223097, 3953],
#  ['Rapid City, SD', 223293, 9247],
#  ['Tucson, AZ', 223782, 14700],
#  ['Watertown, WI', 224600, 11832],
#  ['Barre, VT', 225148, 5640],
#  ['Red Bluff, CA', 225459, 17333],
#  ['Fargo, ND', 225982, 2580],
#  ['Jacksonville, FL', 227325, 8646],
#  ['Sevierville, TN', 227905, 20786],
#  ['New Haven, CT', 228593, 3747],
#  ['Vero Beach, FL', 228694, 185],
#  ['Tampa, FL', 229468, 8524],
#  ['Jefferson, GA', 230128, 7663],
#  ['Hanford, CA', 230222, 7903],
#  ['Gainesville, GA', 230843, 7424],
#  ['Bakersfield, CA', 231043, 9217],
#  ['Yakima, WA', 231069, 23416],
#  ['Dover, DE', 231717, 7849],
#  ['Melbourne, FL', 232285, 6633],
#  ['Pittsfield, MA', 233807, 7292],
#  ['Lancaster, PA', 234466, 3266],
#  ['Kerrville, TX', 235136, 10205],
#  ['Springfield, MA', 235805, 8484],
#  ['Hartford, CT', 235859, 2404],
#  ['Rochester, MN', 236374, 11525],
#  ['Payson, AZ', 236570, 11850],
#  ['Charlotte, NC', 237051, 12212],
#  ['Whitewater, WI', 237130, 14111],
#  ['Racine, WI', 237770, 10592],
#  ['Chicago, IL', 238978, 2432],
#  ['Atlanta, GA', 239115, 10979],
#  ['Winchester, VA', 239504, 5678],
#  ['Port St. Lucie, FL', 239622, 7825],
#  ['Fairbanks, AK', 240281, -3548],
#  ['Fort Myers, FL', 240330, 1453],
#  ['Fergus Falls, MN', 241376, 9356],
#  ['New London, CT', 242074, 6410],
#  ['Virginia Beach, VA', 242407, 7348],
#  ['Idaho Falls, ID', 242903, 25227],
#  ['Torrington, CT', 243490, 4548],
#  ['El Centro, CA', 244025, 6445],
#  ['Faribault, MN', 245772, 7839],
#  ['Richmond, VA', 246524, 9130],
#  ['Clearlake, CA', 247927, 1620],
#  ['Kingston, NY', 248828, 11477],
#  ['Philadelphia, PA', 248836, 7541],
#  ['Traverse City, MI', 249668, 10585],
#  ['Lake Havasu City, AZ', 249846, 16063],
#  ['Lewiston, ID', 250280, 12477],
#  ['Salisbury, MD', 250393, 3761],
#  ['Hudson, NY', 252413, 2323],
#  ['Trenton, NJ', 253283, 7647],
#  ['Dallas-Fort Worth, TX', 253299, 5559],
#  ['State College, PA', 254283, 6858],
#  ['Orlando, FL', 256306, 9181],
#  ['Centralia, WA', 259116, 21525],
#  ['Billings, MT', 259525, 5487],
#  ['Wilmington, NC', 259729, 12927],
#  ['Fresno, CA', 262422, 8735],
#  ['Rexburg, ID', 262583, 16175],
#  ['Georgetown, SC', 264041, 7903],
#  ['Midland, TX', 266110, 1871],
#  ['Durham, NC', 267749, 11209],
#  ['Concord, NH', 268711, 8114],
#  ['Laconia, NH', 270535, 14033],
#  ['Grand Junction, CO', 271624, 15882],
#  ['Walla Walla, WA', 271919, 12266],
#  ['Crestview-Fort Walton Beach-Destin, FL', 272066, 16154],
#  ['Charleston, SC', 272133, 6694],
#  ['Bismarck, ND', 272618, 6308],
#  ['Logan, ID', 272809, 19589],
#  ['Morehead City, NC', 273298, 10961],
#  ['North Port-Sarasota-Bradenton, FL', 273549, 5237],
#  ['Madera, CA', 275165, 13397],
#  ['Asheville, NC', 275298, 9634],
#  ['Spokane, WA', 275433, 24464],
#  ['Boone, NC', 275603, 17211],
#  ['Sonora, CA', 276041, 1983],
#  ['Redding, CA', 276230, 11491],
#  ['Merced, CA', 276890, 5335],
#  ['Albany, OR', 279013, 15502],
#  ['Nashville, TN', 280704, 10473],
#  ['Helena, MT', 281590, 17106],
#  ['Madison, WI', 281874, 10932],
#  ['Raleigh, NC', 283186, 9300],
#  ['Fernley, NV', 283273, 17447],
#  ['The Villages, FL', 283807, 12147],
#  ['Cheyenne, WY', 286134, 19523],
#  ['Ann Arbor, MI', 287343, 3012],
#  ['Phoenix, AZ', 288708, 18083],
#  ['Las Vegas, NV', 290420, 3506],
#  ['Baltimore, MD', 291130, 3463],
#  ['Longview, WA', 292172, 23448],
#  ['Minneapolis-St Paul, MN', 292183, 10861],
#  ['California-Lexington Park, MD', 294206, 3115],
#  ['Worcester, MA', 294822, 11158],
#  ['Charlottesville, VA', 297779, 9941],
#  ['Grants Pass, OR', 298108, 1938],
#  ['Miami-Fort Lauderdale, FL', 299657, 5162],
#  ['Shelton, WA', 299870, 23332],
#  ['Salem, OR', 301146, 9455],
#  ['Yuba City, CA', 303495, 15204],
#  ['Manchester, NH', 307391, 13441],
#  ['Kennewick, WA', 307850, 29183],
#  ['Elko, NV', 307935, -1316],
#  ['Hilton Head Island, SC', 310642, 6099],
#  ['Port Angeles, WA', 313018, 18371],
#  ['Boise City, ID', 313183, 27462],
#  ['Portland, ME', 313897, 16611],
#  ['Burlington, VT', 314529, 11140],
#  ['Providence, RI', 315970, 9973],
#  ['Eugene, OR', 316518, 21465],
#  ['Anchorage, AK', 319060, 26562],
#  ['Prescott, AZ', 320013, 11817],
#  ['Colorado Springs, CO', 321040, 18267],
#  ['Medford, OR', 321139, 2053],
#  ['Eureka, CA', 324676, 3103],
#  ['Ogden, UT', 326096, 19467],
#  ['Modesto, CA', 327789, 12091],
#  ['Chico, CA', 328225, 31503],
#  ['St. George, UT', 328730, 12057],
#  ['Missoula, MT', 334765, 17300],
#  ['Austin, TX', 337558, 12831],
#  ['Carson City, NV', 340938, 17019],
#  ['Naples, FL', 342120, -3384],
#  ['Olympia, WA', 348527, 22402],
#  ['Kalispell, MT', 350757, 22289],
#  ["Coeur d'Alene, ID", 352718, 33926],
#  ['Provo, UT', 356308, 14223],
#  ['Wenatchee, WA', 358846, 17864],
#  ['Greeley, CO', 360010, 6653],
#  ['Ukiah, CA', 366164, -20963],
#  ['Flagstaff, AZ', 366725, 13015],
#  ['Santa Fe, NM', 379156, 26052],
#  ['Stockton, CA', 381335, 8550],
#  ['Reno, NV', 382210, 7658],
#  ['Salt Lake City, UT', 382461, 18496],
#  ['Corvallis, OR', 382677, 13649],
#  ['Riverside, CA', 382754, 11657],
#  ['Hilo, HI', 387463, 17453],
#  ['Mount Vernon, WA', 389562, 19449],
#  ['Ocean City, NJ', 394334, 9991],
#  ['Bremerton, WA', 400956, 24209],
#  ['Fort Collins, CO', 410259, 8885],
#  ['Stamford, CT', 410720, -2240],
#  ['Portland, OR', 418051, 7660],
#  ['Bend, OR', 420896, 15504],
#  ['Bellingham, WA', 421976, 26301],
#  ['Oak Harbor, WA', 424296, 18760],
#  ['Durango, CO', 426655, 9370],
#  ['Sacramento, CA', 427699, 16493],
#  ['Washington, DC', 434156, 13255],
#  ['Barnstable Town, MA', 435346, 3507],
#  ['Denver, CO', 437537, 10007],
#  ['Vallejo, CA', 448395, 8189],
#  ['Bozeman, MT', 450946, 31469],
#  ['Truckee, CA', 461354, 3499],
#  ['New York, NY', 481486, 3841],
#  ['Boston, MA', 490327, 9250],
#  ['Seattle, WA', 531353, 15844],
#  ['Glenwood Springs, CO', 532165, 13423],
#  ['Boulder, CO', 573192, 13592],
#  ['Salinas, CA', 597625, 12287],
#  ['Kapaa, HI', 597760, 33715],
#  ['San Diego, CA', 606086, 21400],
#  ['Key West, FL', 613072, 10573],
#  ['San Luis Obispo, CA', 615790, 12373],
#  ['Ventura, CA', 616909, 12178],
#  ['Santa Rosa, CA', 636587, 317],
#  ['Santa Maria-Santa Barbara, CA', 639124, 8985],
#  ['Greenville, MS', 656050, 18871],
#  ['Los Angeles-Long Beach-Anaheim, CA', 674786, 15235],
#  ['Napa, CA', 683244, -14667],
#  ['Urban Honolulu, HI', 695942, -8732],
#  ['Kahului, HI', 696187, 19627],
#  ['Edwards, CO', 758382, 10829],
#  ['Santa Cruz, CA', 824300, -3972],
#  ['San Francisco, CA', 1094095, 10695],
#  ['San Jose, CA', 1194002, -35123]]
